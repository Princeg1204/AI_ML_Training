# %% [markdown]
# | Part    | Topics                                              | Questions |
# | ------- | --------------------------------------------------- | --------- |
# | Part 1  | Basics (head, tail, shape, columns, info, describe) | 1–10      |
# | Part 2  | Filtering & Selection                               | 11–20     |
# | Part 3  | Sorting, Aggregation & Statistics                   | 21–30     |
# | Part 4  | Missing Values & Duplicates                         | 31–40     |
# | Part 5  | String Operations & Datetime                        | 41–50     |
# | Part 6  | GroupBy & Aggregation                               | 51–60     |
# | Part 7  | Merge, Join, Concat & Pivot                         | 61–70     |
# | Part 8  | Apply, Map, Lambda & Functions                      | 71–80     |

# %% [markdown]
# | EmployeeID | Name   | Department | Age | Gender | Salary | Experience | City      | JoiningDate | Rating |
# | ---------- | ------ | ---------- | --- | ------ | ------ | ---------- | --------- | ----------- | ------ |
# | 101        | Amit   | HR         | 25  | Male   | 35000  | 2          | Pune      | 2021-05-10  | 4.2    |
# | 102        | Priya  | IT         | 30  | Female | 70000  | 6          | Mumbai    | 2018-07-15  | 4.8    |
# | 103        | Rahul  | Finance    | 28  | Male   | 55000  | 4          | Delhi     | 2020-01-20  | 4.1    |
# | 104        | Sneha  | IT         | 35  | Female | 90000  | 10         | Bangalore | 2015-09-12  | 4.9    |
# | 105        | Arjun  | Sales      | 27  | Male   | 45000  | 3          | Hyderabad | 2021-03-18  | 3.9    |
# | 106        | Neha   | HR         | 29  | Female | 50000  | 5          | Pune      | 2019-11-25  | 4.3    |
# | 107        | Karan  | Finance    | 40  | Male   | 100000 | 15         | Delhi     | 2010-04-01  | 4.7    |
# | 108        | Pooja  | Sales      | 31  | Female | 65000  | 7          | Mumbai    | 2017-06-30  | 4.5    |
# | 109        | Vivek  | IT         | 26  | Male   | 60000  | 3          | Bangalore | 2022-01-05  | 4.0    |
# | 110        | Anjali | Marketing  | 33  | Female | 75000  | 8          | Chennai   | 2016-08-17  | 4.6    |

# %% [markdown]
# ### Q. Convert this data into data frame

# %%
import pandas as pd

# Create DataFrame
df = pd.DataFrame({
    "EmployeeID": [101, 102, 103, 104, 105, 106, 107, 108, 109, 110],
    "Name": ["Amit", "Priya", "Rahul", "Sneha", "Arjun", "Neha", "Karan", "Pooja", "Vivek", "Anjali"],
    "Department": ["HR", "IT", "Finance", "IT", "Sales", "HR", "Finance", "Sales", "IT", "Marketing"],
    "Age": [25, 30, 28, 35, 27, 29, 40, 31, 26, 33],
    "Gender": ["Male", "Female", "Male", "Female", "Male", "Female", "Male", "Female", "Male", "Female"],
    "Salary": [35000, 70000, 55000, 90000, 45000, 50000, 100000, 65000, 60000, 75000],
    "Experience": [2, 6, 4, 10, 3, 5, 15, 7, 3, 8],
    "City": ["Pune", "Mumbai", "Delhi", "Bangalore", "Hyderabad", "Pune", "Delhi", "Mumbai", "Bangalore", "Chennai"],
    "JoiningDate": [
        "2021-05-10", "2018-07-15", "2020-01-20", "2015-09-12", "2021-03-18",
        "2019-11-25", "2010-04-01", "2017-06-30", "2022-01-05", "2016-08-17"
    ],
    "Rating": [4.2, 4.8, 4.1, 4.9, 3.9, 4.3, 4.7, 4.5, 4.0, 4.6]
})

# JoiningDate to datetime
df["JoiningDate"] = pd.to_datetime(df["JoiningDate"])

# Display DataFrame
print(df)
# Out:
#    EmployeeID    Name Department  Age  Gender  Salary  Experience       City  \
# 0         101    Amit         HR   25    Male   35000           2       Pune
# 1         102   Priya         IT   30  Female   70000           6     Mumbai
# 2         103   Rahul    Finance   28    Male   55000           4      Delhi
# 3         104   Sneha         IT   35  Female   90000          10  Bangalore
# 4         105   Arjun      Sales   27    Male   45000           3  Hyderabad
# 5         106    Neha         HR   29  Female   50000           5       Pune
# 6         107   Karan    Finance   40    Male  100000          15      Delhi
# 7         108   Pooja      Sales   31  Female   65000           7     Mumbai
# 8         109   Vivek         IT   26    Male   60000           3  Bangalore
# 9         110  Anjali  Marketing   33  Female   75000           8    Chennai
#
#   JoiningDate  Rating
# 0  2021-05-10     4.2
# 1  2018-07-15     4.8
# 2  2020-01-20     4.1
# 3  2015-09-12     4.9
# ...

# %% [markdown]
# ### 1. Display the first five rows.

# %%
df.head()
# Out:
#    EmployeeID   Name Department  Age  Gender  Salary  Experience       City  \
# 0         101   Amit         HR   25    Male   35000           2       Pune
# 1         102  Priya         IT   30  Female   70000           6     Mumbai
# 2         103  Rahul    Finance   28    Male   55000           4      Delhi
# 3         104  Sneha         IT   35  Female   90000          10  Bangalore
# 4         105  Arjun      Sales   27    Male   45000           3  Hyderabad
#
#   JoiningDate  Rating
# 0  2021-05-10     4.2
# 1  2018-07-15     4.8
# 2  2020-01-20     4.1
# 3  2015-09-12     4.9
# 4  2021-03-18     3.9

# %% [markdown]
# ### 2. Display the last five rows.

# %%
df.tail()
# Out:
#    EmployeeID    Name Department  Age  Gender  Salary  Experience       City  \
# 5         106    Neha         HR   29  Female   50000           5       Pune
# 6         107   Karan    Finance   40    Male  100000          15      Delhi
# 7         108   Pooja      Sales   31  Female   65000           7     Mumbai
# 8         109   Vivek         IT   26    Male   60000           3  Bangalore
# 9         110  Anjali  Marketing   33  Female   75000           8    Chennai
#
#   JoiningDate  Rating
# 5  2019-11-25     4.3
# 6  2010-04-01     4.7
# 7  2017-06-30     4.5
# 8  2022-01-05     4.0
# 9  2016-08-17     4.6

# %% [markdown]
# ### 3. Find the number of rows and columns.

# %%
df.shape
# Out:
# (10, 10)

# %% [markdown]
# ### 4. Display column names.

# %%
df.columns
# Out:
# Index(['EmployeeID', 'Name', 'Department', 'Age', 'Gender', 'Salary',
#        'Experience', 'City', 'JoiningDate', 'Rating'],
#       dtype='object')

# %% [markdown]
# ### 5. Display data types.

# %%
df.dtypes
# Out:
# EmployeeID              int64
# Name                   object
# Department             object
# Age                     int64
# Gender                 object
# Salary                  int64
# Experience              int64
# City                   object
# JoiningDate    datetime64[ns]
# Rating                float64
# dtype: object

# %% [markdown]
# ### 6. Display dataset information.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   EmployeeID   10 non-null     int64
#  1   Name         10 non-null     object
#  2   Department   10 non-null     object
#  3   Age          10 non-null     int64
#  4   Gender       10 non-null     object
#  5   Salary       10 non-null     int64
#  6   Experience   10 non-null     int64
#  7   City         10 non-null     object
#  8   JoiningDate  10 non-null     datetime64[ns]
#  9   Rating       10 non-null     float64
# dtypes: datetime64[ns](1), float64(1), int64(4), object(4)
# memory usage: 932.0+ bytes

# %% [markdown]
# ### 7. Generate summary statistics.

# %%
df.describe()
# Out:
#        EmployeeID        Age         Salary  Experience          JoiningDate  \
# count    10.00000  10.000000      10.000000   10.000000                   10
# mean    105.50000  30.400000   64500.000000    6.300000  2018-04-24 19:12:00
# min     101.00000  25.000000   35000.000000    2.000000  2010-04-01 00:00:00
# 25%     103.25000  27.250000   51250.000000    3.250000  2016-11-04 06:00:00
# 50%     105.50000  29.500000   62500.000000    5.500000  2019-03-21 00:00:00
# 75%     107.75000  32.500000   73750.000000    7.750000  2020-12-02 06:00:00
# max     110.00000  40.000000  100000.000000   15.000000  2022-01-05 00:00:00
# std       3.02765   4.575296   20062.402648    3.945462                  NaN
#
#           Rating
# count  10.000000
# mean    4.400000
# min     3.900000
# 25%     4.125000
# 50%     4.400000
# 75%     4.675000
# max     4.900000
# std     0.349603

# %% [markdown]
# ### 8. Check missing values.

# %%
df.isnull().sum()
# Out:
# EmployeeID     0
# Name           0
# Department     0
# Age            0
# Gender         0
# Salary         0
# Experience     0
# City           0
# JoiningDate    0
# Rating         0
# dtype: int64

# %% [markdown]
# ### 9. Display only the Name column.

# %%
df["Name"]
# Out:
# 0      Amit
# 1     Priya
# 2     Rahul
# 3     Sneha
# 4     Arjun
# 5      Neha
# 6     Karan
# 7     Pooja
# 8     Vivek
# 9    Anjali
# Name: Name, dtype: object

# %% [markdown]
# ### 10. Display Name and Salary columns.

# %%
df[["Name", "Salary"]]
# Out:
#      Name  Salary
# 0    Amit   35000
# 1   Priya   70000
# 2   Rahul   55000
# 3   Sneha   90000
# 4   Arjun   45000
# 5    Neha   50000
# 6   Karan  100000
# 7   Pooja   65000
# 8   Vivek   60000
# 9  Anjali   75000

# %% [markdown]
# ### 11. Find employee names older than 30.

# %%
df[df["Age"] > 30]
# Out:
#    EmployeeID    Name Department  Age  Gender  Salary  Experience       City  \
# 3         104   Sneha         IT   35  Female   90000          10  Bangalore
# 6         107   Karan    Finance   40    Male  100000          15      Delhi
# 7         108   Pooja      Sales   31  Female   65000           7     Mumbai
# 9         110  Anjali  Marketing   33  Female   75000           8    Chennai
#
#   JoiningDate  Rating
# 3  2015-09-12     4.9
# 6  2010-04-01     4.7
# 7  2017-06-30     4.5
# 9  2016-08-17     4.6

# %% [markdown]
# ### 12. Find IT department employees.

# %%
df[df["Department"] == "IT"]
# Out:
#    EmployeeID   Name Department  Age  Gender  Salary  Experience       City  \
# 1         102  Priya         IT   30  Female   70000           6     Mumbai
# 3         104  Sneha         IT   35  Female   90000          10  Bangalore
# 8         109  Vivek         IT   26    Male   60000           3  Bangalore
#
#   JoiningDate  Rating
# 1  2018-07-15     4.8
# 3  2015-09-12     4.9
# 8  2022-01-05     4.0

# %% [markdown]
# ### 13. Find employees earning more than ₹60,000.

# %%
df[df["Salary"] > 60000]
# Out:
#    EmployeeID    Name Department  Age  Gender  Salary  Experience       City  \
# 1         102   Priya         IT   30  Female   70000           6     Mumbai
# 3         104   Sneha         IT   35  Female   90000          10  Bangalore
# 6         107   Karan    Finance   40    Male  100000          15      Delhi
# 7         108   Pooja      Sales   31  Female   65000           7     Mumbai
# 9         110  Anjali  Marketing   33  Female   75000           8    Chennai
#
#   JoiningDate  Rating
# 1  2018-07-15     4.8
# 3  2015-09-12     4.9
# 6  2010-04-01     4.7
# 7  2017-06-30     4.5
# 9  2016-08-17     4.6

# %% [markdown]
# ### 14. Display only female employees.

# %%
df[df["Gender"] == "Female"]
# Out:
#    EmployeeID    Name Department  Age  Gender  Salary  Experience       City  \
# 1         102   Priya         IT   30  Female   70000           6     Mumbai
# 3         104   Sneha         IT   35  Female   90000          10  Bangalore
# 5         106    Neha         HR   29  Female   50000           5       Pune
# 7         108   Pooja      Sales   31  Female   65000           7     Mumbai
# 9         110  Anjali  Marketing   33  Female   75000           8    Chennai
#
#   JoiningDate  Rating
# 1  2018-07-15     4.8
# 3  2015-09-12     4.9
# 5  2019-11-25     4.3
# 7  2017-06-30     4.5
# 9  2016-08-17     4.6

# %% [markdown]
# ### 15. Display employees from Pune.

# %%
df[df["City"] == "Pune"]
# Out:
#    EmployeeID  Name Department  Age  Gender  Salary  Experience  City  \
# 0         101  Amit         HR   25    Male   35000           2  Pune
# 5         106  Neha         HR   29  Female   50000           5  Pune
#
#   JoiningDate  Rating
# 0  2021-05-10     4.2
# 5  2019-11-25     4.3

# %% [markdown]
# ### 16. Count total employees.

# %%
len(df)
# Out:
# 10

# %% [markdown]
# ### 17. Count male employees.

# %%
(df["Gender"] == "Male").sum()
# Out:
# np.int64(5)

# %% [markdown]
# ### 18. Count female employees.

# %%
(df["Gender"] == "Female").sum()
# Out:
# np.int64(5)

# %% [markdown]
# ### 19. Find maximum salary.

# %%
df["Salary"].max()
# Out:
# 100000

# %% [markdown]
# ### 20. Find minimum salary.

# %%
df["Salary"].min()
# Out:
# 35000

# %% [markdown]
# ### 21. Average Salary

# %%
df["Salary"].mean()
# Out:
# np.float64(64500.0)

# %% [markdown]
# ### 22. Median Salary

# %%
df["Salary"].median()
# Out:
# 62500.0

# %% [markdown]
# ### 23. Highest-Paid Employee

# %%
df[df["Salary"] == df["Salary"].max()]
# Out:
#    EmployeeID   Name Department  Age Gender  Salary  Experience   City  \
# 6         107  Karan    Finance   40   Male  100000          15  Delhi
#
#   JoiningDate  Rating
# 6  2010-04-01     4.7

# %% [markdown]
# ### 24. Lowest-Paid Employee

# %%
df[df["Salary"] == df["Salary"].min()]
# Out:
#    EmployeeID  Name Department  Age Gender  Salary  Experience  City  \
# 0         101  Amit         HR   25   Male   35000           2  Pune
#
#   JoiningDate  Rating
# 0  2021-05-10     4.2

# %% [markdown]
# ### 25. Employees with More Than 5 Years of Experience

# %%
df[df["Experience"] > 5]
# Out:
#    EmployeeID    Name Department  Age  Gender  Salary  Experience       City  \
# 1         102   Priya         IT   30  Female   70000           6     Mumbai
# 3         104   Sneha         IT   35  Female   90000          10  Bangalore
# 6         107   Karan    Finance   40    Male  100000          15      Delhi
# 7         108   Pooja      Sales   31  Female   65000           7     Mumbai
# 9         110  Anjali  Marketing   33  Female   75000           8    Chennai
#
#   JoiningDate  Rating
# 1  2018-07-15     4.8
# 3  2015-09-12     4.9
# 6  2010-04-01     4.7
# 7  2017-06-30     4.5
# 9  2016-08-17     4.6

# %% [markdown]
# ### 26. IT Employees with Salary > ₹70,000

# %%
df[(df["Department"] == "IT") & (df["Salary"] > 70000)]
# Out:
#    EmployeeID   Name Department  Age  Gender  Salary  Experience       City  \
# 3         104  Sneha         IT   35  Female   90000          10  Bangalore
#
#   JoiningDate  Rating
# 3  2015-09-12     4.9

# %% [markdown]
# ### 27. Sort Salary (Ascending)

# %%
df.sort_values(by="Salary")
# Out:
#    EmployeeID    Name Department  Age  Gender  Salary  Experience       City  \
# 0         101    Amit         HR   25    Male   35000           2       Pune
# 4         105   Arjun      Sales   27    Male   45000           3  Hyderabad
# 5         106    Neha         HR   29  Female   50000           5       Pune
# 2         103   Rahul    Finance   28    Male   55000           4      Delhi
# 8         109   Vivek         IT   26    Male   60000           3  Bangalore
# 7         108   Pooja      Sales   31  Female   65000           7     Mumbai
# 1         102   Priya         IT   30  Female   70000           6     Mumbai
# 9         110  Anjali  Marketing   33  Female   75000           8    Chennai
# 3         104   Sneha         IT   35  Female   90000          10  Bangalore
# 6         107   Karan    Finance   40    Male  100000          15      Delhi
#
#   JoiningDate  Rating
# 0  2021-05-10     4.2
# 4  2021-03-18     3.9
# 5  2019-11-25     4.3
# 2  2020-01-20     4.1
# ...

# %% [markdown]
# ### 28. Sort Salary (Descending)

# %%
df.sort_values(by="Salary", ascending=False)
# Out:
#    EmployeeID    Name Department  Age  Gender  Salary  Experience       City  \
# 6         107   Karan    Finance   40    Male  100000          15      Delhi
# 3         104   Sneha         IT   35  Female   90000          10  Bangalore
# 9         110  Anjali  Marketing   33  Female   75000           8    Chennai
# 1         102   Priya         IT   30  Female   70000           6     Mumbai
# 7         108   Pooja      Sales   31  Female   65000           7     Mumbai
# 8         109   Vivek         IT   26    Male   60000           3  Bangalore
# 2         103   Rahul    Finance   28    Male   55000           4      Delhi
# 5         106    Neha         HR   29  Female   50000           5       Pune
# 4         105   Arjun      Sales   27    Male   45000           3  Hyderabad
# 0         101    Amit         HR   25    Male   35000           2       Pune
#
#   JoiningDate  Rating
# 6  2010-04-01     4.7
# 3  2015-09-12     4.9
# 9  2016-08-17     4.6
# 1  2018-07-15     4.8
# ...

# %% [markdown]
# ### 29. Top 3 Highest-Paid Employees

# %%
df.nlargest(3, "Salary")
# Out:
#    EmployeeID    Name Department  Age  Gender  Salary  Experience       City  \
# 6         107   Karan    Finance   40    Male  100000          15      Delhi
# 3         104   Sneha         IT   35  Female   90000          10  Bangalore
# 9         110  Anjali  Marketing   33  Female   75000           8    Chennai
#
#   JoiningDate  Rating
# 6  2010-04-01     4.7
# 3  2015-09-12     4.9
# 9  2016-08-17     4.6

# %% [markdown]
# ### 30. Bottom 3 Lowest Salaries

# %%
df.nsmallest(3, "Salary")
# Out:
#    EmployeeID   Name Department  Age  Gender  Salary  Experience       City  \
# 0         101   Amit         HR   25    Male   35000           2       Pune
# 4         105  Arjun      Sales   27    Male   45000           3  Hyderabad
# 5         106   Neha         HR   29  Female   50000           5       Pune
#
#   JoiningDate  Rating
# 0  2021-05-10     4.2
# 4  2021-03-18     3.9
# 5  2019-11-25     4.3

# %% [markdown]
# ### 31. Count Employees in Each Department

# %%
df["Department"].value_counts()
# Out:
# Department
# IT           3
# HR           2
# Finance      2
# Sales        2
# Marketing    1
# Name: count, dtype: int64

# %% [markdown]
# ### 32. Average Salary by Department

# %%
df.groupby("Department")["Salary"].mean()
# Out:
# Department
# Finance      77500.000000
# HR           42500.000000
# IT           73333.333333
# Marketing    75000.000000
# Sales        55000.000000
# Name: Salary, dtype: float64

# %% [markdown]
# ### 33. Count Employees by City

# %%
df.groupby("City").size()
# Out:
# City
# Bangalore    2
# Chennai      1
# Delhi        2
# Hyderabad    1
# Mumbai       2
# Pune         2
# dtype: int64

# %%
df["City"].value_counts()
# Out:
# City
# Pune         2
# Mumbai       2
# Delhi        2
# Bangalore    2
# Hyderabad    1
# Chennai      1
# Name: count, dtype: int64

# %% [markdown]
# ### 34. Average Rating by Department

# %%
df.groupby("Department")["Rating"].mean()
# Out:
# Department
# Finance      4.400000
# HR           4.250000
# IT           4.566667
# Marketing    4.600000
# Sales        4.200000
# Name: Rating, dtype: float64

# %% [markdown]
# ### 35. Maximum Salary by Department

# %%
df.groupby("Department")["Salary"].max()
# Out:
# Department
# Finance      100000
# HR            50000
# IT            90000
# Marketing     75000
# Sales         65000
# Name: Salary, dtype: int64

# %% [markdown]
# ### 36. Minimum Salary by City

# %%
df.groupby("City")["Salary"].min()
# Out:
# City
# Bangalore    60000
# Chennai      75000
# Delhi        55000
# Hyderabad    45000
# Mumbai       65000
# Pune         35000
# Name: Salary, dtype: int64

# %% [markdown]
# ### 37. Rename Columns

# %%
df.rename(columns={
    "Salary": "MonthlySalary",
    "Experience": "YearsExperience"
})
# Out:
#    EmployeeID    Name Department  Age  Gender  MonthlySalary  YearsExperience  \
# 0         101    Amit         HR   25    Male          35000                2
# 1         102   Priya         IT   30  Female          70000                6
# 2         103   Rahul    Finance   28    Male          55000                4
# 3         104   Sneha         IT   35  Female          90000               10
# 4         105   Arjun      Sales   27    Male          45000                3
# 5         106    Neha         HR   29  Female          50000                5
# 6         107   Karan    Finance   40    Male         100000               15
# 7         108   Pooja      Sales   31  Female          65000                7
# 8         109   Vivek         IT   26    Male          60000                3
# 9         110  Anjali  Marketing   33  Female          75000                8
#
#         City JoiningDate  Rating
# 0       Pune  2021-05-10     4.2
# 1     Mumbai  2018-07-15     4.8
# ...

# %% [markdown]
# ### 38. Add Bonus Column (10%)

# %%
df["Bonus"] = df["Salary"] * 0.10
df['Bonus']
# Out:
# 0     3500.0
# 1     7000.0
# 2     5500.0
# 3     9000.0
# 4     4500.0
# 5     5000.0
# 6    10000.0
# 7     6500.0
# 8     6000.0
# 9     7500.0
# Name: Bonus, dtype: float64

# %% [markdown]
# ### 39. Add Tax Column (5%)

# %%
df["Tax"] = df["Salary"] * 0.05
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_820/3677404785.py in <cell line: 0>()
# ----> 1 df["Tax"] = df["Salary"] * 0.05
#
# NameError: name 'df' is not defined

# %% [markdown]
# ### 40. Convert JoiningDate to Datetime

# %%
df["JoiningDate"] = pd.to_datetime(df["JoiningDate"])
df["JoiningDate"].dtype
# Out:
# dtype('<M8[ns]')

# %% [markdown]
# >In pandas, <M8[ns] is the low-level NumPy representation for the datetime64[ns] data type, which represents dates and times with nanosecond precision

# %% [markdown]
# ### 41. Calculate Years Since Joining

# %%
df["YearsSinceJoining"] = (
    pd.Timestamp.today() - df["JoiningDate"]
).dt.days // 365

# %% [markdown]
# ### 42. Set EmployeeID as Index

# %%
df.set_index("EmployeeID", inplace=True)

# %% [markdown]
# ### 43. Reset Index

# %%
df.reset_index(inplace=True)

# %% [markdown]
# ### 44. Remove Duplicate Rows

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (10, 13)

# %% [markdown]
# ### 45. Check Unique Cities

# %%
df["City"].unique()
# Out:
# array(['Pune', 'Mumbai', 'Delhi', 'Bangalore', 'Hyderabad', 'Chennai'],
#       dtype=object)

# %% [markdown]
# ### 46. Count Unique Cities

# %%
df["City"].nunique()
# Out:
# 6

# %% [markdown]
# ### 47. Check Unique Departments

# %%
df["Department"].unique()
# Out:
# array(['HR', 'IT', 'Finance', 'Sales', 'Marketing'], dtype=object)

# %% [markdown]
# ### 48. Count Unique Departments

# %%
df["Department"].nunique()
# Out:
# 5

# %% [markdown]
# ### 49. Filter with Multiple Conditions

# %%
df[
    (df["Salary"] > 50000) &
    (df["Experience"] > 5)
]
# Out:
#    EmployeeID    Name Department  Age  Gender  Salary  Experience       City  \
# 1         102   Priya         IT   30  Female   70000           6     Mumbai
# 3         104   Sneha         IT   35  Female   90000          10  Bangalore
# 6         107   Karan    Finance   40    Male  100000          15      Delhi
# 7         108   Pooja      Sales   31  Female   65000           7     Mumbai
# 9         110  Anjali  Marketing   33  Female   75000           8    Chennai
#
#   JoiningDate  Rating    Bonus     Tax  YearsSinceJoining
# 1  2018-07-15     4.8   7000.0  3500.0                  8
# 3  2015-09-12     4.9   9000.0  4500.0                 10
# 6  2010-04-01     4.7  10000.0  5000.0                 16
# 7  2017-06-30     4.5   6500.0  3250.0                  9
# 9  2016-08-17     4.6   7500.0  3750.0                  9

# %% [markdown]
# ### 50. Using query()

# %%
df.query("Salary > 50000 and Experience > 5")
# Out:
#    EmployeeID    Name Department  Age  Gender  Salary  Experience       City  \
# 1         102   Priya         IT   30  Female   70000           6     Mumbai
# 3         104   Sneha         IT   35  Female   90000          10  Bangalore
# 6         107   Karan    Finance   40    Male  100000          15      Delhi
# 7         108   Pooja      Sales   31  Female   65000           7     Mumbai
# 9         110  Anjali  Marketing   33  Female   75000           8    Chennai
#
#   JoiningDate  Rating    Bonus     Tax  YearsSinceJoining
# 1  2018-07-15     4.8   7000.0  3500.0                  8
# 3  2015-09-12     4.9   9000.0  4500.0                 10
# 6  2010-04-01     4.7  10000.0  5000.0                 16
# 7  2017-06-30     4.5   6500.0  3250.0                  9
# 9  2016-08-17     4.6   7500.0  3750.0                  9

# %% [markdown]
# ### 51. Using loc[]

# %%
df.loc[:, ["Name", "Salary"]]
# Out:
#      Name  Salary
# 0    Amit   35000
# 1   Priya   70000
# 2   Rahul   55000
# 3   Sneha   90000
# 4   Arjun   45000
# 5    Neha   50000
# 6   Karan  100000
# 7   Pooja   65000
# 8   Vivek   60000
# 9  Anjali   75000

# %%
df.loc[0:4]
# Out:
#    EmployeeID   Name Department  Age  Gender  Salary  Experience       City  \
# 0         101   Amit         HR   25    Male   35000           2       Pune
# 1         102  Priya         IT   30  Female   70000           6     Mumbai
# 2         103  Rahul    Finance   28    Male   55000           4      Delhi
# 3         104  Sneha         IT   35  Female   90000          10  Bangalore
# 4         105  Arjun      Sales   27    Male   45000           3  Hyderabad
#
#   JoiningDate  Rating   Bonus     Tax  YearsSinceJoining
# 0  2021-05-10     4.2  3500.0  1750.0                  5
# 1  2018-07-15     4.8  7000.0  3500.0                  8
# 2  2020-01-20     4.1  5500.0  2750.0                  6
# 3  2015-09-12     4.9  9000.0  4500.0                 10
# 4  2021-03-18     3.9  4500.0  2250.0                  5

# %% [markdown]
# ### 52. Using iloc[]

# %%
df.iloc[: ,[1,5]]
# Out:
#      Name  Salary
# 0    Amit   35000
# 1   Priya   70000
# 2   Rahul   55000
# 3   Sneha   90000
# 4   Arjun   45000
# 5    Neha   50000
# 6   Karan  100000
# 7   Pooja   65000
# 8   Vivek   60000
# 9  Anjali   75000

# %%
df.iloc[0:5]
# Out:
#    EmployeeID   Name Department  Age  Gender  Salary  Experience       City  \
# 0         101   Amit         HR   25    Male   35000           2       Pune
# 1         102  Priya         IT   30  Female   70000           6     Mumbai
# 2         103  Rahul    Finance   28    Male   55000           4      Delhi
# 3         104  Sneha         IT   35  Female   90000          10  Bangalore
# 4         105  Arjun      Sales   27    Male   45000           3  Hyderabad
#
#   JoiningDate  Rating   Bonus     Tax  YearsSinceJoining
# 0  2021-05-10     4.2  3500.0  1750.0                  5
# 1  2018-07-15     4.8  7000.0  3500.0                  8
# 2  2020-01-20     4.1  5500.0  2750.0                  6
# 3  2015-09-12     4.9  9000.0  4500.0                 10
# 4  2021-03-18     3.9  4500.0  2250.0                  5

# %% [markdown]
# ### 53. Random Sample

# %%
df.sample(3)
# Out:
#    EmployeeID   Name Department  Age  Gender  Salary  Experience    City  \
# 0         101   Amit         HR   25    Male   35000           2    Pune
# 6         107  Karan    Finance   40    Male  100000          15   Delhi
# 7         108  Pooja      Sales   31  Female   65000           7  Mumbai
#
#   JoiningDate  Rating    Bonus     Tax  YearsSinceJoining
# 0  2021-05-10     4.2   3500.0  1750.0                  5
# 6  2010-04-01     4.7  10000.0  5000.0                 16
# 7  2017-06-30     4.5   6500.0  3250.0                  9

# %% [markdown]
# ### 54. Create Salary Categories using pd.cut()

# %%
df["SalaryCategory"] = pd.cut(
    df["Salary"],
    bins=[0,40000,60000,80000,100000],
    labels=["Low","Medium","High","Very High"]
)

# %%
df["SalaryCategory"]
# Out:
# 0          Low
# 1         High
# 2       Medium
# 3    Very High
# 4       Medium
# 5       Medium
# 6    Very High
# 7         High
# 8       Medium
# 9         High
# Name: SalaryCategory, dtype: category
# Categories (4, object): ['Low' < 'Medium' < 'High' < 'Very High']

# %% [markdown]
# ### 55. Sort by Department then Salary

# %%
df.sort_values(
    by=["Department","Salary"],
    ascending=[True,False]
)
# Out:
#    EmployeeID    Name Department  Age  Gender  Salary  Experience       City  \
# 6         107   Karan    Finance   40    Male  100000          15      Delhi
# 2         103   Rahul    Finance   28    Male   55000           4      Delhi
# 5         106    Neha         HR   29  Female   50000           5       Pune
# 0         101    Amit         HR   25    Male   35000           2       Pune
# 3         104   Sneha         IT   35  Female   90000          10  Bangalore
# 1         102   Priya         IT   30  Female   70000           6     Mumbai
# 8         109   Vivek         IT   26    Male   60000           3  Bangalore
# 9         110  Anjali  Marketing   33  Female   75000           8    Chennai
# 7         108   Pooja      Sales   31  Female   65000           7     Mumbai
# 4         105   Arjun      Sales   27    Male   45000           3  Hyderabad
#
#   JoiningDate  Rating    Bonus     Tax  YearsSinceJoining SalaryCategory
# ...

# %% [markdown]
# ### 56. nlargest()

# %%
df.nlargest(5, "Salary")
# Out:
#    EmployeeID    Name Department  Age  Gender  Salary  Experience       City  \
# 6         107   Karan    Finance   40    Male  100000          15      Delhi
# 3         104   Sneha         IT   35  Female   90000          10  Bangalore
# 9         110  Anjali  Marketing   33  Female   75000           8    Chennai
# 1         102   Priya         IT   30  Female   70000           6     Mumbai
# 7         108   Pooja      Sales   31  Female   65000           7     Mumbai
#
#   JoiningDate  Rating    Bonus     Tax  YearsSinceJoining SalaryCategory
# 6  2010-04-01     4.7  10000.0  5000.0                 16      Very High
# 3  2015-09-12     4.9   9000.0  4500.0                 10      Very High
# 9  2016-08-17     4.6   7500.0  3750.0                  9           High
# 1  2018-07-15     4.8   7000.0  3500.0                  8           High
# 7  2017-06-30     4.5   6500.0  3250.0                  9           High

# %% [markdown]
# ### 57. nsmallest()

# %%
df.nsmallest(5, "Salary")
# Out:
#    EmployeeID   Name Department  Age  Gender  Salary  Experience       City  \
# 0         101   Amit         HR   25    Male   35000           2       Pune
# 4         105  Arjun      Sales   27    Male   45000           3  Hyderabad
# 5         106   Neha         HR   29  Female   50000           5       Pune
# 2         103  Rahul    Finance   28    Male   55000           4      Delhi
# 8         109  Vivek         IT   26    Male   60000           3  Bangalore
#
#   JoiningDate  Rating   Bonus     Tax  YearsSinceJoining SalaryCategory
# 0  2021-05-10     4.2  3500.0  1750.0                  5            Low
# 4  2021-03-18     3.9  4500.0  2250.0                  5         Medium
# 5  2019-11-25     4.3  5000.0  2500.0                  6         Medium
# 2  2020-01-20     4.1  5500.0  2750.0                  6         Medium
# 8  2022-01-05     4.0  6000.0  3000.0                  4         Medium

# %% [markdown]
# ### 58. assign()

# %%
df = df.assign(
    HRA=df["Salary"]*0.20,
    PF=df["Salary"]*0.12
)

# %% [markdown]
# ### 59. pipe()

# %%
def add_bonus(data):
    data["Bonus"] = data["Salary"] * 0.10
    return data

df.pipe(add_bonus)
# Out:
#    EmployeeID    Name Department  Age  Gender  Salary  Experience       City  \
# 0         101    Amit         HR   25    Male   35000           2       Pune
# 1         102   Priya         IT   30  Female   70000           6     Mumbai
# 2         103   Rahul    Finance   28    Male   55000           4      Delhi
# 3         104   Sneha         IT   35  Female   90000          10  Bangalore
# 4         105   Arjun      Sales   27    Male   45000           3  Hyderabad
# 5         106    Neha         HR   29  Female   50000           5       Pune
# 6         107   Karan    Finance   40    Male  100000          15      Delhi
# 7         108   Pooja      Sales   31  Female   65000           7     Mumbai
# 8         109   Vivek         IT   26    Male   60000           3  Bangalore
# 9         110  Anjali  Marketing   33  Female   75000           8    Chennai
#
#   JoiningDate  Rating    Bonus     Tax  YearsSinceJoining SalaryCategory  \
# ...

# %% [markdown]
# ### 60. apply() to Classify Salary

# %%
def classify_salary(salary):
    if salary < 50000:
        return "Low"
    elif salary < 80000:
        return "Medium"
    else:
        return "High"

df["SalaryLevel"] = df["Salary"].apply(classify_salary)

# %%
df["SalaryLevel"] = df["Salary"].apply(
    lambda x: "High"
    if x >= 80000
    else "Medium"
    if x >= 50000
    else "Low"
)

# %% [markdown]
# ### Bonus 1. map() to Encode Gender

# %%
df["GenderCode"] = df["Gender"].map({
    "Male": 1,
    "Female": 0
})

# %% [markdown]
# ### Bonus 2. replace() to Rename Departments

# %%
df["Department"] = df["Department"].replace({
    "HR": "Human Resources",
    "IT": "Information Technology"
})

# %% [markdown]
# ### Bonus 3. Export to CSV

# %%
df.to_csv("employee_output.csv", index=False)

# %% [markdown]
# ### Bonus 4. Export to Excel

# %%
df.to_excel("employee_output.xlsx", index=False)

# %% [markdown]
# ### 61. Create a Pivot Table of Average Salary by City and Department

# %%
pivot = df.pivot_table(
    values="Salary",
    index="City",
    columns="Department",
    aggfunc="mean"
)

print(pivot)
# Out:
# Department  Finance  Human Resources  Information Technology  Marketing  \
# City
# Bangalore       NaN              NaN                 75000.0        NaN
# Chennai         NaN              NaN                     NaN    75000.0
# Delhi       77500.0              NaN                     NaN        NaN
# Hyderabad       NaN              NaN                     NaN        NaN
# Mumbai          NaN              NaN                 70000.0        NaN
# Pune            NaN          42500.0                     NaN        NaN
#
# Department    Sales
# City
# Bangalore       NaN
# Chennai         NaN
# Delhi           NaN
# Hyderabad   45000.0
# Mumbai      65000.0
# Pune            NaN

# %% [markdown]
# ### 62. Use groupby() with Multiple Aggregations

# %%
result = df.groupby("Department").agg({
    "Salary": ["min", "max", "mean", "sum"],
    "Age": ["min", "max", "mean"],
    "Rating": ["mean", "max"]
})

print(result)
# Out:
#                        Salary                               Age      \
#                           min     max          mean     sum min max
# Department
# Finance                 55000  100000  77500.000000  155000  28  40
# Human Resources         35000   50000  42500.000000   85000  25  29
# Information Technology  60000   90000  73333.333333  220000  26  35
# Marketing               75000   75000  75000.000000   75000  33  33
# Sales                   45000   65000  55000.000000  110000  27  31
#
#                                      Rating
#                              mean      mean  max
# Department
# Finance                 34.000000  4.400000  4.7
# Human Resources         27.000000  4.250000  4.3
# Information Technology  30.333333  4.566667  4.9
# Marketing               33.000000  4.600000  4.6
# Sales                   29.000000  4.200000  4.5

# %% [markdown]
# ### 63. Rank Employees by Salary

# %%
df["SalaryRank"] = df["Salary"].rank(ascending=False)

print(df)
# Out:
#    EmployeeID    Name              Department  Age  Gender  Salary  \
# 0         101    Amit         Human Resources   25    Male   35000
# 1         102   Priya  Information Technology   30  Female   70000
# 2         103   Rahul                 Finance   28    Male   55000
# 3         104   Sneha  Information Technology   35  Female   90000
# 4         105   Arjun                   Sales   27    Male   45000
# 5         106    Neha         Human Resources   29  Female   50000
# 6         107   Karan                 Finance   40    Male  100000
# 7         108   Pooja                   Sales   31  Female   65000
# 8         109   Vivek  Information Technology   26    Male   60000
# 9         110  Anjali               Marketing   33  Female   75000
#
#    Experience       City JoiningDate  Rating    Bonus     Tax  \
# 0           2       Pune  2021-05-10     4.2   3500.0  1750.0
# 1           6     Mumbai  2018-07-15     4.8   7000.0  3500.0
# ...

# %% [markdown]
# ### 64. Calculate Cumulative Salary

# %%
df["CumulativeSalary"] = df["Salary"].cumsum()

print(df)
# Out:
#    EmployeeID    Name              Department  Age  Gender  Salary  \
# 0         101    Amit         Human Resources   25    Male   35000
# 1         102   Priya  Information Technology   30  Female   70000
# 2         103   Rahul                 Finance   28    Male   55000
# 3         104   Sneha  Information Technology   35  Female   90000
# 4         105   Arjun                   Sales   27    Male   45000
# 5         106    Neha         Human Resources   29  Female   50000
# 6         107   Karan                 Finance   40    Male  100000
# 7         108   Pooja                   Sales   31  Female   65000
# 8         109   Vivek  Information Technology   26    Male   60000
# 9         110  Anjali               Marketing   33  Female   75000
#
#    Experience       City JoiningDate  Rating    Bonus     Tax  \
# 0           2       Pune  2021-05-10     4.2   3500.0  1750.0
# 1           6     Mumbai  2018-07-15     4.8   7000.0  3500.0
# ...

# %% [markdown]
# ### 65. Find Duplicate Rows

# %%
duplicates = df[df.duplicated()]

print(duplicates)
# Out:
# Empty DataFrame
# Columns: [EmployeeID, Name, Department, Age, Gender, Salary, Experience, City, JoiningDate, Rating, Bonus, Tax, YearsSinceJoining, SalaryCategory, HRA, PF, SalaryLevel, GenderCode, SalaryRank, CumulativeSalary]
# Index: []

# %% [markdown]
# ### 66. Find Unique Ratings

# %%
print(df["Rating"].unique())
# Out:
# [4.2 4.8 4.1 4.9 3.9 4.3 4.7 4.5 4.  4.6]
