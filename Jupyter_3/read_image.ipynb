# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
img = mpimg.imread(r"D:\IMAGES\PRINCE_4.png")
img
# Out:
# array([[[0.07450981, 0.08627451, 0.11372549],
#         [0.06666667, 0.07450981, 0.10588235],
#         [0.07058824, 0.07843138, 0.10980392],
#         ...,
#         [0.0627451 , 0.07450981, 0.10196079],
#         [0.06666667, 0.07450981, 0.10196079],
#         [0.06666667, 0.07843138, 0.10588235]],
#
#        [[0.06666667, 0.07450981, 0.10588235],
#         [0.06666667, 0.07450981, 0.10588235],
#         [0.07058824, 0.07450981, 0.10588235],
#         ...,
#         [0.0627451 , 0.07450981, 0.10196079],
#         [0.0627451 , 0.07450981, 0.10196079],
#         [0.06666667, 0.07450981, 0.10196079]],
#
#        [[0.07058824, 0.07450981, 0.10588235],
#         [0.0627451 , 0.07058824, 0.10196079],
#         [0.07058824, 0.07450981, 0.10588235],
#         ...,
#         [0.0627451 , 0.07450981, 0.10196079],
#         [0.06666667, 0.07843138, 0.10588235],
#         [0.06666667, 0.07843138, 0.10588235]],
#
#        ...,
#
#        [[0.30980393, 0.19607843, 0.15294118],
#         [0.3019608 , 0.18431373, 0.14509805],
#         [0.30980393, 0.19215687, 0.14901961],
#         ...,
#         [0.07843138, 0.04705882, 0.03921569],
#         [0.08627451, 0.05490196, 0.04705882],
#         [0.08627451, 0.05490196, 0.04705882]],
#
#        [[0.29803923, 0.18039216, 0.14117648],
#         [0.2901961 , 0.1764706 , 0.13725491],
#         [0.29803923, 0.18431373, 0.14117648],
#         ...,
#         [0.08235294, 0.05490196, 0.04313726],
#         [0.08627451, 0.05882353, 0.04705882],
#         [0.09019608, 0.05882353, 0.05098039]],
#
#        [[0.2901961 , 0.18431373, 0.14509805],
#         [0.2901961 , 0.1764706 , 0.14117648],
#         [0.2901961 , 0.1764706 , 0.13725491],
#         ...,
#         [0.09019608, 0.05882353, 0.05098039],
#         [0.09411765, 0.0627451 , 0.05490196],
#         [0.09803922, 0.07058824, 0.0627451 ]]],
#       shape=(1448, 1086, 3), dtype=float32)

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (1448, 1086, 3)

# %%
img.ndim
# Out:
# 3

# %%
plt.imshow(img)

# %%
plt.axis('off')
plt.imshow(img)
plt.show()

# %%
plt.figure(figsize = (12,9))
plt.axis('off')
plt.imshow(img)
plt.show()

# %%
plt.figure(figsize = (12,9))
plt.axis('off')
plt.imshow(img)
plt.colorbar()
plt.show()

# %%
plt.figure(figsize = (12,9))
plt.axis('off')
plt.imshow(img, cmap = 'Accent')
plt.colorbar()
plt.show()

# %%
plt.figure(figsize = (12,9))
plt.axis('off')
plt.imshow(img, cmap = 'hot')
plt.colorbar()
plt.show()

# %%
plt.figure(figsize = (12,9))
plt.axis('off')
plt.imshow(img, cmap = 'nipy_spectral')
plt.colorbar()
plt.show()
